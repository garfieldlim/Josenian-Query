# %%
import openai
import pinecone
import pandas as pd
from langchain.embeddings.openai import OpenAIEmbeddings
import re

OPENAI_API_KEY = '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'
PINECONE_API_KEY = '69d02c68-4ee9-4ce6-b3b2-7437b74f85a7'
PINECONE_ENVIRONMENT = 'us-west1-gcp'

index_name = 'rmrj-articles'
pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_ENVIRONMENT)
# index = pinecone.Index(index_name)
index = pinecone.GRPCIndex(index_name)

index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'rmrj': {'vector_count': 151}},
#  'total_vector_count': 151}

# %%
from openai.embeddings_utils import get_embedding
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"
max_tokens = 8000
openai.api_key = OPENAI_API_KEY
def get_embedding(text, model=embedding_model):
   text = text.replace("\n", " ")
   return openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']

# %%
from langchain.vectorstores import Pinecone

text_field = "text"

index = pinecone.Index(index_name)

vectorstore = Pinecone(index, get_embedding, text_field)
query = "What is the DOI of Jovelyn Cuizon's paper?"
# query = get_embedding(query)
# query_response = vectorstore.max_marginal_relevance_search_by_vector(embedding=query, namespace='rmrj')
query_response = vectorstore.similarity_search(query, namespace='rmrj', k=4)
# Out:
# ---------------------------------------------------------------------------
# ApiValueError                             Traceback (most recent call last)
# Cell In[90], line 11
#       8 query = "What is the DOI of Jovelyn Cuizon's paper?"
#       9 # query = get_embedding(query)
#      10 # query_response = vectorstore.max_marginal_relevance_search_by_vector(embedding=query, namespace='rmrj')
# ---> 11 query_response = vectorstore.similarity_search(query, namespace='rmrj', filter={"author": {"$in": {"Jovelyn", "Cuizon"}},
#      12     },)
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain/vectorstores/pinecone.py:158, in Pinecone.similarity_search(self, query, k, filter, namespace, **kwargs)
#     139 def similarity_search(
#     140     self,
#     141     query: str,
#    (...)
#     145     **kwargs: Any,
#     146 ) -> List[Document]:
#     147     """Return pinecone documents most similar to query.
#     148
#     149     Args:
#    (...)
# ...

# %%
results = []
for document in query_response:
    abstract = document.page_content
    metadata = document.metadata
    print("\nAbstract: ", abstract,"\nMetadata: ", metadata)
    print("\n")
