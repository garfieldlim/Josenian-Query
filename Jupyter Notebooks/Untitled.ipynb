# %%
import json
with open("title.json") as f:
    data = json.load(f)

# %%
data[150]
# Out:
# {'uuid': '9990c9b3-34c0-4fb0-9f72-8fc15fdd6e0d',
#  'title': 'Utilization of Wastewater from Different Sources as Potential Electrical Energy Source',
#  'data_lists_embeds': [0.021332882344722748,
#   -0.02678072266280651,
#   0.020105769857764244,
#   0.009034785442054272,
#   -0.009513494558632374,
#   0.006617643404752016,
#   0.0026463831309229136,
#   -0.0305564533919096,
#   -0.016761550679802895,
#   -0.024650130420923233,
#   0.013026272878050804,
#   0.04552453011274338,
#   0.016748065128922462,
#   0.013255513273179531,
#   0.00011135457316413522,
#   0.006344576831907034,
#   0.026308756321668625,
#   -0.004753375891596079,
#   1.3418911294138525e-05,
#   0.0035802023485302925,
#   -0.007645855657756329,
#   0.012466655112802982,
#   0.0013720737770199776,
#   -0.017017759382724762,
#   -0.02195318043231964,
#   0.025931183248758316,
#   0.009729250334203243,
#   -0.03522218018770218,
#   -0.025337854400277138,
#   -0.0023514041677117348,
#   0.01662670262157917,
# ...
