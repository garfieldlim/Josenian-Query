# %% [markdown]
# ## Loading

# %%
import pandas as pd
import os
import numpy as np
from langchain.embeddings.openai import OpenAIEmbeddings
import tiktoken
import json
import pinecone
from tqdm.auto import tqdm
from tqdm.autonotebook import tqdm

OPENAI_API_KEY = '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'
PINECONE_API_KEY = '69d02c68-4ee9-4ce6-b3b2-7437b74f85a7'
PINECONE_ENVIRONMENT = 'us-west1-gcp'

index_name = 'rmrj-articles'
path = "for_upserting/"

data = pd.read_csv(path + 'combined-rmrj-articles.csv')
data
# Out:
# /opt/homebrew/lib/python3.11/site-packages/pinecone/index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#                                                  Title
# 0    Timeless Existence and Principle of Creation: ...  \
# 1    Ratooning Response of Lowland Rice (Oryza sati...
# 2    Paternal Resilience in Time of Pandemic: A Phe...
# 3    An Inquiry into the Problems Concerning Filipi...
# 4    Correlating the Psychological and Spiritual We...
# ..                                                 ...
# 146  DSS Framework: A Proposal for Disaster Logisti...
# 147  Ratooning Response of Lowland Rice NSIC Rc352 ...
# 148  Direct and Indirect Factors Affecting Teachers...
# 149  Graduate Education during COVID-19 Pandemic: I...
# 150  Kakugi Ko, Kalambuan Mo (KKK Mo) as an Extensi...
#
#                                               Keywords
# ...

# %% [markdown]
# ## Text Splitter as text_splitter

# %%
tokenizer = tiktoken.get_encoding('cl100k_base')

def tiktoken_len(text):
    tokens = tokenizer.encode(text, disallowed_special=())
    return len(tokens)

from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=20, length_function=tiktoken_len, separators=["\n\n", "\n", " ", ""])

# %% [markdown]
# ##  Embedder ada as embed

# %%
model_name = 'text-embedding-ada-002'

embed = OpenAIEmbeddings(model=model_name, openai_api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Create index

# %%
pinecone.init(api_key=PINECONE_API_KEY, environment=PINECONE_ENVIRONMENT)
dimension_count=1536 #1536 is the dimensions for ada-002

if index_name not in pinecone.list_indexes():
    pinecone.create_index(name=index_name, metric='cosine', dimension=dimension_count)

# %%
index = pinecone.GRPCIndex(index_name)

index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 176}},
#  'total_vector_count': 176}

# %% [markdown]
# ## Formatting

# %%
metadata_labels = ["Title", "Published Date", "Author", "DOI", "Link", "Abstract"]
# Now create the new DataFrame 'data_for_upserting'
data_formatted = data[['id', "Title", "Published Date", "Author", "DOI", "Link", "Abstract", 'summary']].copy()
# Renaming the 'summary' column to 'embed'
data_formatted.rename(columns={'summary': 'Embed', 'id': 'ID'}, inplace=True)
data = data_formatted
data
# Out:
#                                        ID
# 0    111553fe-23fc-45e4-ad46-0c56b61aee0e  \
# 1    737dc86a-c28d-4002-ab11-4e1ae1ae946d
# 2    c4d3893e-977e-42ab-904a-80a94a67b9b1
# 3    449a1ec7-c2d8-4674-b714-a039305e9602
# 4    a9e24e6e-cfd0-4bc5-a30a-8786816b040e
# ..                                    ...
# 146  259299d7-d843-4bd6-aecb-483df94d02bb
# 147  43eba709-e6de-4435-85a9-c9116bdfb7b1
# 148  d940566f-1d0a-4981-a3cc-6069057e6c36
# 149  f88b3737-6d5f-492f-b6ad-a334edb07fb7
# 150  9990c9b3-34c0-4fb0-9f72-8fc15fdd6e0d
#
#                                                  Title Published Date
# 0    Timeless Existence and Principle of Creation: ...     2022-05-25  \
# 1    Ratooning Response of Lowland Rice (Oryza sati...     2022-06-14
# 2    Paternal Resilience in Time of Pandemic: A Phe...     2022-05-26
# 3    An Inquiry into the Problems Concerning Filipi...     2022-05-27
# 4    Correlating the Psychological and Spiritual We...     2022-05-31
# ...

# %%
records_json = []
texts = []
metadatas = []
batch_limit = 100

for i, record in data.iterrows():
    metadata = {}
    for label in metadata_labels:
        metadata[label] = record[label]
    record_texts = text_splitter.split_text(record['Embed'])
    record_metadatas = [{'chunk': j, 'text': text, **metadata} for j, text in enumerate(record_texts)]
    texts.extend(record_texts)
    metadatas.extend(record_metadatas)
    
if len(texts) > 0:
    ids = data['ID']
    records_json.extend([(id, meta, text) for id, meta, text in zip(ids, metadatas, texts)])
records_json
# Out:
# [('111553fe-23fc-45e4-ad46-0c56b61aee0e',
#   {'chunk': 0,
# ...

# %%
import asyncio

data_json = []

async def get_embedding(i, record):
    embeddings = await embed.embed_documents(record[2])
    new_record = {
        'uuid': record[0],
        'metadata': record[1],
        'text': embeddings
    }
    data_json.append(new_record)
    print(f"Append count: {i}")
    count = count + 1

async def main():
    tasks = [get_embedding(i, record) for i, record in enumerate(records_json)]
    await asyncio.gather(*tasks)

# Run the event loop until the main() coroutine is done
asyncio.run(main())

data_json
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 21
#      18     await asyncio.gather(*tasks)
#      20 # Run the event loop until the main() coroutine is done
# ---> 21 asyncio.run(main())
#      23 data_json
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# ...
